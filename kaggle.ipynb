# %%
import torch

checkpoint = torch.load('/content/drive/MyDrive/ml/weight/latest_checkpoint.pth')
start_epoch = checkpoint['epoch']
print(start_epoch, 'load parameter')

# %%
# !tar -xvf /content/drive/MyDrive/ml/khu_competition.tar

# %%
# !find /content/train -type f | wc -l

# %%
# !find /content/test -type f | wc -l

# %%
cd /content/drive/MyDrive/ml

# %%
# !nvidia-smi

# %%
import train
import importlib
importlib.reload(train)

train.main()

# %%
import eval
import importlib
importlib.reload(eval)

eval.main()
